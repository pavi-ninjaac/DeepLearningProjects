# %% [markdown]
# <a href="https://colab.research.google.com/github/pavi-ninjaac/DeepLearningProjects/blob/main/FiveWays_of_image_read_display.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Five Ways to load and show an image in DL

# %%
# import libraries
import numpy as np
from IPython.display import Image
import matplotlib.pyplot as plt
import cv2
from PIL import Image
from keras.preprocessing.image import load_img
import keras

# %%
#load file from local system
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b6bdadf-2a2c-401b-809e-1cdcb13d56b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b6bdadf-2a2c-401b-809e-1cdcb13d56b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat_dog.jpg to cat_dog.jpg

# %%
filename = 'cat_dog.jpg'

# %% [markdown]
# ## 1) Using IPython

# %%
# auto return the image 
from IPython.display import Image
Image(filename = filename , width =224, height = 224)

# %% [markdown]
# ## 2)Using matplotlib

# %%
img = plt.imread(filename) 
plt.imshow(img)

# %% [markdown]
# ## 3)Using the keras API

# %%
keras_img = load_img(filename,target_size=(224,224))

input_arr=keras.preprocessing.image.img_to_array(keras_img)
input_arr = np.array([input_arr])  # Convert single image to a batch.

# %%
plt.imshow(keras_img)

# %% [markdown]
# # Using the Opencv

# %%
cv_img = cv2.imread(filename)
cv2.imshow('The image',cv_img) #openin image through colab will crash the secsion but it will work fine in jupyter notebook
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-21-a36fd3f1d2c4> in <module>()
#       1 cv_img = cv2.imread(filename)
# ----> 2 cv2.imshow('The image',cv_img)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
# here we are using the plt imshow to show the image
plt.imshow(cv_img)

# %% [markdown]
# #### The default color pattern in cv2 is BGR we need change it to RGB before displaying it

# %%
plt.imshow(cv2.cvtColor(cv_img,cv2.COLOR_BGR2RGB))

# %% [markdown]
# ### resizing the image

# %%
img = cv2.resize(cv_img,(250,250))
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 5) Using the PIL Python Image Library

# %%
from PIL import Image 
pillow_img = Image.open(filename)
img = pillow_img.resize((224,224))
plt.imshow(img)
